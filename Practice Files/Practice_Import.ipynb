# %%
import time
import pandas as pd
from config import db_password
from sqlalchemy import create_engine

# %%
file = 'aac_shelter_outcomes.csv'
df = pd.read_csv(file)
df.head()
# Out:
#   age_upon_outcome animal_id animal_type                    breed  \
# 0          2 weeks   A684346         Cat   Domestic Shorthair Mix
# 1           1 year   A666430         Dog               Beagle Mix
# 2           1 year   A675708         Dog                 Pit Bull
# 3          9 years   A680386         Dog  Miniature Schnauzer Mix
# 4         5 months   A683115       Other                  Bat Mix
#
#           color        date_of_birth             datetime  \
# 0  Orange Tabby  2014-07-07T00:00:00  2014-07-22T16:04:00
# 1   White/Brown  2012-11-06T00:00:00  2013-11-07T11:47:00
# 2    Blue/White  2013-03-31T00:00:00  2014-06-03T14:20:00
# 3         White  2005-06-02T00:00:00  2014-06-15T15:50:00
# 4         Brown  2014-01-07T00:00:00  2014-07-07T14:04:00
#
#              monthyear     name outcome_subtype outcome_type sex_upon_outcome
# 0  2014-07-22T16:04:00      NaN         Partner     Transfer      Intact Male
# 1  2013-11-07T11:47:00     Lucy         Partner     Transfer    Spayed Female
# 2  2014-06-03T14:20:00  *Johnny             NaN     Adoption    Neutered Male
# 3  2014-06-15T15:50:00   Monday         Partner     Transfer    Neutered Male
# 4  2014-07-07T14:04:00      NaN     Rabies Risk   Euthanasia          Unknown

# %%
df.count()
# Out:
# age_upon_outcome    78248
# animal_id           78256
# animal_type         78256
# breed               78256
# color               78256
# date_of_birth       78256
# datetime            78256
# monthyear           78256
# name                54370
# outcome_subtype     35963
# outcome_type        78244
# sex_upon_outcome    78254
# dtype: int64

# %%
dfdogs = df[df["animal_type"] == "Dog"]
dfdogs
# Out:
#       age_upon_outcome animal_id animal_type  \
# 1               1 year   A666430         Dog
# 2               1 year   A675708         Dog
# 3              9 years   A680386         Dog
# 5             4 months   A664462         Dog
# 7              3 years   A692618         Dog
# ...                ...       ...         ...
# 78250          1 month   A764895         Dog
# 78251          1 month   A764894         Dog
# 78252          3 years   A764468         Dog
# 78254         2 months   A765858         Dog
# 78255         2 months   A765857         Dog
#
#                                      breed        color        date_of_birth  \
# 1                               Beagle Mix  White/Brown  2012-11-06T00:00:00
# 2                                 Pit Bull   Blue/White  2013-03-31T00:00:00
# 3                  Miniature Schnauzer Mix        White  2005-06-02T00:00:00
# 5                           Leonberger Mix  Brown/White  2013-06-03T00:00:00
# 7                  Chihuahua Shorthair Mix        Brown  2011-11-23T00:00:00
# ...                                    ...          ...                  ...
# 78250  Golden Retriever/Labrador Retriever  Brown/White  2017-12-04T00:00:00
# 78251  Golden Retriever/Labrador Retriever  Brown/White  2017-12-04T00:00:00
# 78252                          Mastiff Mix   Blue/White  2014-12-30T00:00:00
# 78254                   Standard Schnauzer          Red  2017-11-13T00:00:00
# 78255               Labrador Retriever Mix  White/Brown  2017-11-13T00:00:00
#
#                   datetime            monthyear     name outcome_subtype  \
# 1      2013-11-07T11:47:00  2013-11-07T11:47:00     Lucy         Partner
# 2      2014-06-03T14:20:00  2014-06-03T14:20:00  *Johnny             NaN
# 3      2014-06-15T15:50:00  2014-06-15T15:50:00   Monday         Partner
# 5      2013-10-07T13:06:00  2013-10-07T13:06:00   *Edgar         Partner
# 7      2014-12-08T15:55:00  2014-12-08T15:55:00    *Ella         Partner
# ...                    ...                  ...      ...             ...
# 78250  2018-02-01T18:40:00  2018-02-01T18:40:00      NaN          Foster
# 78251  2018-02-01T18:26:00  2018-02-01T18:26:00      NaN          Foster
# 78252  2018-02-01T18:06:00  2018-02-01T18:06:00      Max             NaN
# 78254  2018-02-01T18:32:00  2018-02-01T18:32:00      NaN             NaN
# 78255  2018-02-01T18:44:00  2018-02-01T18:44:00      NaN             NaN
#
#       outcome_type sex_upon_outcome
# 1         Transfer    Spayed Female
# 2         Adoption    Neutered Male
# 3         Transfer    Neutered Male
# 5         Transfer      Intact Male
# 7         Transfer    Spayed Female
# ...            ...              ...
# 78250     Adoption    Neutered Male
# 78251     Adoption    Spayed Female
# 78252     Adoption    Neutered Male
# 78254     Adoption    Spayed Female
# 78255     Adoption    Neutered Male
#
# [44242 rows x 12 columns]

# %%
dfdogs_cleaned = dfdogs.drop(columns = ["age_upon_outcome", "animal_type", "color", "name", "outcome_subtype", "monthyear"])
dfdogs_cleaned.head(15)
# Out:
#    animal_id                                 breed        date_of_birth  \
# 1    A666430                            Beagle Mix  2012-11-06T00:00:00
# 2    A675708                              Pit Bull  2013-03-31T00:00:00
# 3    A680386               Miniature Schnauzer Mix  2005-06-02T00:00:00
# 5    A664462                        Leonberger Mix  2013-06-03T00:00:00
# 7    A692618               Chihuahua Shorthair Mix  2011-11-23T00:00:00
# 11   A673652                Papillon/Border Collie  2012-02-28T00:00:00
# 12   A677679        Chihuahua Shorthair/Pomeranian  2014-03-07T00:00:00
# 13   A640655  Miniature Schnauzer/Miniature Poodle  2009-04-27T00:00:00
# 14   A690350                Labrador Retriever Mix  2006-10-18T00:00:00
# 15   A680396                       Rat Terrier Mix  2012-06-02T00:00:00
# 16   A674298                          Pit Bull Mix  2013-03-11T00:00:00
# 18   A692378    German Shepherd/Labrador Retriever  2014-10-19T00:00:00
# 22   A666660                            Beagle Mix  2012-05-05T00:00:00
# 25   A689952                           Mastiff Mix  2013-10-11T00:00:00
# 26   A669621                       Plott Hound Mix  2013-08-23T00:00:00
#
#                datetime     outcome_type sex_upon_outcome
# 1   2013-11-07T11:47:00         Transfer    Spayed Female
# 2   2014-06-03T14:20:00         Adoption    Neutered Male
# 3   2014-06-15T15:50:00         Transfer    Neutered Male
# 5   2013-10-07T13:06:00         Transfer      Intact Male
# 7   2014-12-08T15:55:00         Transfer    Spayed Female
# 11  2014-03-28T14:39:00         Transfer    Neutered Male
# 12  2014-05-26T19:10:00         Adoption    Neutered Male
# 13  2014-04-25T11:17:00  Return to Owner    Spayed Female
# 14  2014-10-26T18:20:00  Return to Owner    Neutered Male
# 15  2014-06-15T15:11:00         Transfer    Neutered Male
# 16  2014-04-16T12:51:00         Transfer    Neutered Male
# 18  2014-12-21T18:20:00         Adoption    Spayed Female
# 22  2014-12-11T17:52:00         Adoption    Spayed Female
# 25  2014-10-19T17:54:00         Adoption    Spayed Female
# 26  2013-12-25T09:47:00         Transfer    Intact Female

# %%
dfdogs_cleaned["date_of_birth"] = pd.to_datetime(dfdogs_cleaned["date_of_birth"])
dfdogs_cleaned["datetime"] = pd.to_datetime(dfdogs_cleaned["datetime"])
dfdogs_cleaned.head(15)
# Out:
#    animal_id                                 breed date_of_birth  \
# 1    A666430                            Beagle Mix    2012-11-06
# 2    A675708                              Pit Bull    2013-03-31
# 3    A680386               Miniature Schnauzer Mix    2005-06-02
# 5    A664462                        Leonberger Mix    2013-06-03
# 7    A692618               Chihuahua Shorthair Mix    2011-11-23
# 11   A673652                Papillon/Border Collie    2012-02-28
# 12   A677679        Chihuahua Shorthair/Pomeranian    2014-03-07
# 13   A640655  Miniature Schnauzer/Miniature Poodle    2009-04-27
# 14   A690350                Labrador Retriever Mix    2006-10-18
# 15   A680396                       Rat Terrier Mix    2012-06-02
# 16   A674298                          Pit Bull Mix    2013-03-11
# 18   A692378    German Shepherd/Labrador Retriever    2014-10-19
# 22   A666660                            Beagle Mix    2012-05-05
# 25   A689952                           Mastiff Mix    2013-10-11
# 26   A669621                       Plott Hound Mix    2013-08-23
#
#               datetime     outcome_type sex_upon_outcome
# 1  2013-11-07 11:47:00         Transfer    Spayed Female
# 2  2014-06-03 14:20:00         Adoption    Neutered Male
# 3  2014-06-15 15:50:00         Transfer    Neutered Male
# 5  2013-10-07 13:06:00         Transfer      Intact Male
# 7  2014-12-08 15:55:00         Transfer    Spayed Female
# 11 2014-03-28 14:39:00         Transfer    Neutered Male
# 12 2014-05-26 19:10:00         Adoption    Neutered Male
# 13 2014-04-25 11:17:00  Return to Owner    Spayed Female
# 14 2014-10-26 18:20:00  Return to Owner    Neutered Male
# 15 2014-06-15 15:11:00         Transfer    Neutered Male
# 16 2014-04-16 12:51:00         Transfer    Neutered Male
# 18 2014-12-21 18:20:00         Adoption    Spayed Female
# 22 2014-12-11 17:52:00         Adoption    Spayed Female
# 25 2014-10-19 17:54:00         Adoption    Spayed Female
# 26 2013-12-25 09:47:00         Transfer    Intact Female

# %%
top_breeds = ['Pit Bull Mix', 'Chihuahua Shorthair Mix', 'Labrador Retriever Mix', 'German Shepherd Mix', 'Australian Cattle Dog Mix',
              'Dachshund Mix', 'Boxer Mix', 'Miniature Poodle Mix', 'Border Collie Mix', 'Catahoula Mix', 'Rat Terrier Mix', 
              'Australian Shepherd Mix', 'Yorkshire Terrier Mix', 'Siberian Husky Mix', 'Jack Russell Terrier Mix']
dfdogs_cleaned = dfdogs_cleaned[dfdogs_cleaned.breed.isin(top_breeds)]
dfdogs_cleaned.head(10)
# Out:
#    animal_id                    breed date_of_birth            datetime  \
# 7    A692618  Chihuahua Shorthair Mix    2011-11-23 2014-12-08 15:55:00
# 14   A690350   Labrador Retriever Mix    2006-10-18 2014-10-26 18:20:00
# 15   A680396          Rat Terrier Mix    2012-06-02 2014-06-15 15:11:00
# 16   A674298             Pit Bull Mix    2013-03-11 2014-04-16 12:51:00
# 27   A667311   Labrador Retriever Mix    2013-09-01 2013-11-19 18:30:00
# 28   A690699  Chihuahua Shorthair Mix    2014-06-17 2014-11-04 18:03:00
# 32   A669918   Labrador Retriever Mix    2013-09-30 2014-01-03 17:47:00
# 34   A678098   Labrador Retriever Mix    2002-05-08 2014-07-09 11:54:00
# 36   A677038  Chihuahua Shorthair Mix    2012-04-22 2014-04-26 13:00:00
# 37   A665344  Chihuahua Shorthair Mix    2009-10-16 2013-11-02 17:47:00
#
#        outcome_type sex_upon_outcome
# 7          Transfer    Spayed Female
# 14  Return to Owner    Neutered Male
# 15         Transfer    Neutered Male
# 16         Transfer    Neutered Male
# 27         Adoption    Spayed Female
# 28         Transfer    Intact Female
# 32         Adoption    Spayed Female
# 34         Adoption    Neutered Male
# 36         Adoption    Spayed Female
# 37         Adoption    Spayed Female

# %%
dfdogs_cleaned.reset_index(drop=True)
# Out:
#       animal_id                    breed date_of_birth            datetime  \
# 0       A692618  Chihuahua Shorthair Mix    2011-11-23 2014-12-08 15:55:00
# 1       A690350   Labrador Retriever Mix    2006-10-18 2014-10-26 18:20:00
# 2       A680396          Rat Terrier Mix    2012-06-02 2014-06-15 15:11:00
# 3       A674298             Pit Bull Mix    2013-03-11 2014-04-16 12:51:00
# 4       A667311   Labrador Retriever Mix    2013-09-01 2013-11-19 18:30:00
# ...         ...                      ...           ...                 ...
# 23845   A738395  Chihuahua Shorthair Mix    2015-11-14 2018-02-01 18:23:00
# 23846   A761266        Border Collie Mix    2015-11-01 2018-02-01 18:32:00
# 23847   A725872      German Shepherd Mix    2016-02-03 2018-02-01 18:20:00
# 23848   A761265        Border Collie Mix    2015-11-01 2018-02-01 18:31:00
# 23849   A765857   Labrador Retriever Mix    2017-11-13 2018-02-01 18:44:00
#
#           outcome_type sex_upon_outcome
# 0             Transfer    Spayed Female
# 1      Return to Owner    Neutered Male
# 2             Transfer    Neutered Male
# 3             Transfer    Neutered Male
# 4             Adoption    Spayed Female
# ...                ...              ...
# 23845         Adoption    Neutered Male
# 23846  Return to Owner    Spayed Female
# 23847  Return to Owner    Intact Female
# 23848  Return to Owner    Neutered Male
# 23849         Adoption    Neutered Male
#
# [23850 rows x 6 columns]

# %%
dfdogs_cleaned.count()
# Out:
# animal_id           23850
# breed               23850
# date_of_birth       23850
# datetime            23850
# outcome_type        23847
# sex_upon_outcome    23849
# dtype: int64

# %%
#insert connection string to connect pandas to sql
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5432/Practice"

# %%
#create a database engine so that SQLAlchemy can communicate and convert datatypes between SQL and pandas
engine = create_engine(db_string)

# %%
#import dataframe to sql table
dfdogs_cleaned.to_sql(name='shelter_data_table', con=engine)
