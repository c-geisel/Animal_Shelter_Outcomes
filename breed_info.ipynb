# %%
import pandas as pd

# %%
#Create a dataframe from original Austin Shelter Data set
shelter_df = pd.read_csv('./archive/aac_shelter_outcomes.csv')
shelter_df
# Out:
#       age_upon_outcome animal_id animal_type  \
# 0              2 weeks   A684346         Cat
# 1               1 year   A666430         Dog
# 2               1 year   A675708         Dog
# 3              9 years   A680386         Dog
# 4             5 months   A683115       Other
# ...                ...       ...         ...
# 78251          1 month   A764894         Dog
# 78252          3 years   A764468         Dog
# 78253              NaN   A766098       Other
# 78254         2 months   A765858         Dog
# 78255         2 months   A765857         Dog
#
#                                      breed         color        date_of_birth  \
# 0                   Domestic Shorthair Mix  Orange Tabby  2014-07-07T00:00:00
# 1                               Beagle Mix   White/Brown  2012-11-06T00:00:00
# 2                                 Pit Bull    Blue/White  2013-03-31T00:00:00
# 3                  Miniature Schnauzer Mix         White  2005-06-02T00:00:00
# ...

# %%
#Count the rows
shelter_df.count
# Out:
# <bound method DataFrame.count of       age_upon_outcome animal_id animal_type  \
# 0              2 weeks   A684346         Cat
# 1               1 year   A666430         Dog
# 2               1 year   A675708         Dog
# 3              9 years   A680386         Dog
# 4             5 months   A683115       Other
# ...                ...       ...         ...
# 78251          1 month   A764894         Dog
# 78252          3 years   A764468         Dog
# 78253              NaN   A766098       Other
# 78254         2 months   A765858         Dog
# 78255         2 months   A765857         Dog
#
#                                      breed         color        date_of_birth  \
# 0                   Domestic Shorthair Mix  Orange Tabby  2014-07-07T00:00:00
# 1                               Beagle Mix   White/Brown  2012-11-06T00:00:00
# 2                                 Pit Bull    Blue/White  2013-03-31T00:00:00
# ...

# %%
#Get the value counts of each breed
shelter_df['breed'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                     Domestic Shorthair Mix
# 1                                 Beagle Mix
# 2                                   Pit Bull
# 3                    Miniature Schnauzer Mix
# 4                                    Bat Mix
#                         ...
# 78251    Golden Retriever/Labrador Retriever
# 78252                            Mastiff Mix
# 78253                                Bat Mix
# 78254                     Standard Schnauzer
# 78255                 Labrador Retriever Mix
# Name: breed, Length: 78256, dtype: object>

# %%
#Filter out dogs in the animale type columns and create a new data frame
dog_df = shelter_df.loc[shelter_df['animal_type'] == 'Dog']
dog_df.head()
# Out:
#   age_upon_outcome animal_id animal_type                    breed  \
# 1           1 year   A666430         Dog               Beagle Mix
# 2           1 year   A675708         Dog                 Pit Bull
# 3          9 years   A680386         Dog  Miniature Schnauzer Mix
# 5         4 months   A664462         Dog           Leonberger Mix
# 7          3 years   A692618         Dog  Chihuahua Shorthair Mix
#
#          color        date_of_birth             datetime            monthyear  \
# 1  White/Brown  2012-11-06T00:00:00  2013-11-07T11:47:00  2013-11-07T11:47:00
# 2   Blue/White  2013-03-31T00:00:00  2014-06-03T14:20:00  2014-06-03T14:20:00
# 3        White  2005-06-02T00:00:00  2014-06-15T15:50:00  2014-06-15T15:50:00
# 5  Brown/White  2013-06-03T00:00:00  2013-10-07T13:06:00  2013-10-07T13:06:00
# 7        Brown  2011-11-23T00:00:00  2014-12-08T15:55:00  2014-12-08T15:55:00
#
#       name outcome_subtype outcome_type sex_upon_outcome
# ...

# %%
#Get the count of each dog breed
dog_df['breed'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 1                                 Beagle Mix
# 2                                   Pit Bull
# 3                    Miniature Schnauzer Mix
# 5                             Leonberger Mix
# 7                    Chihuahua Shorthair Mix
#                         ...
# 78250    Golden Retriever/Labrador Retriever
# 78251    Golden Retriever/Labrador Retriever
# 78252                            Mastiff Mix
# 78254                     Standard Schnauzer
# 78255                 Labrador Retriever Mix
# Name: breed, Length: 44242, dtype: object>

# %% [markdown]
# We took the top 15 dog breeds and gathered information on the size and life expectancy of each breed and created a table called Breeds_Info

# %%
#Created a dataframe from the Breeds_Info table 
top_breeds_df = pd.read_csv('Breed_Info2.csv')
top_breeds_df
# Out:
#                          Breed    Size  Average_life_expectancy
# 0                Pit Bull Mix    large                        11
# 1      Chihuahua Shorthair mix   small                        15
# 2       Labrador Retriever Mix  large                         13
# 3           German Sheperd Mix   large                        10
# 4   Australian Cattle Dog Mix   medium                        13
# 5                Dachshund Mix   small                        14
# 6                   Boxer Mix    large                         9
# 7        Miniature Poodle Mix    small                        14
# 8            Border Collie Mix  medium                        12
# 9               Catahoula Mix    large                        12
# 10            Rat Terrier Mix    small                        16
# 11     Australian Shepherd Mix  medium                        13
# 12       Yorkshire Terrier Mix   small                        14
# ...
