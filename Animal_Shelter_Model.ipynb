# %%
import os
# Find the latest version of spark 3.0 from http://www.apache.org/dist/spark/ and enter as the spark version
# For example:
# spark_version = 'spark-3.0.3'
spark_version = 'spark-3.0.3'
os.environ['SPARK_VERSION']=spark_version

# Install Spark and Java
# !apt-get update
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !wget -q http://www.apache.org/dist/spark/$SPARK_VERSION/$SPARK_VERSION-bin-hadoop2.7.tgz
# !tar xf $SPARK_VERSION-bin-hadoop2.7.tgz
# !pip install -q findspark

# Set Environment Variables
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = f"/content/{spark_version}-bin-hadoop2.7"

# Start a SparkSession
import findspark
findspark.init()
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:3 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Hit:6 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:10 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Fetched 3,626 B in 2s (1,658 B/s)
# Reading package lists... Done

# %%
# Download the Postgres driver that will allow Spark to interact with Postgres.
# !wget https://jdbc.postgresql.org/download/postgresql-42.2.16.jar
# Out:
# --2022-01-09 17:00:36--  https://jdbc.postgresql.org/download/postgresql-42.2.16.jar
# Resolving jdbc.postgresql.org (jdbc.postgresql.org)... 72.32.157.228, 2001:4800:3e1:1::228
# Connecting to jdbc.postgresql.org (jdbc.postgresql.org)|72.32.157.228|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1002883 (979K) [application/java-archive]
# Saving to: ‘postgresql-42.2.16.jar’
#
# postgresql-42.2.16. 100%[===================>] 979.38K  --.-KB/s    in 0.09s
#
# 2022-01-09 17:00:36 (11.2 MB/s) - ‘postgresql-42.2.16.jar’ saved [1002883/1002883]

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Animal_Shelter_Project").config("spark.driver.extraClassPath","/content/postgresql-42.2.16.jar").getOrCreate()

# %% [markdown]
# ### Load Amazon Data into Spark DataFrame

# %%
# Read in data from S3 Buckets
from pyspark import SparkFiles
url = "https://c-geisel-bucket.s3.amazonaws.com/Breed_data.csv"
spark.sparkContext.addFile(url)
dog_breed_df = spark.read.csv(SparkFiles.get("Breed_data.csv"), sep=",", header=True, inferSchema=True)
dog_breed_df.show()
# Out:
# +--------------------+------+---------------+
# |               Breed|  Size|life_expectancy|
# +--------------------+------+---------------+
# |        Pit Bull Mix| large|             11|
# |Chihuahua Shortha...| small|             15|
# |Labrador Retrieve...|large |             13|
# | German Shepherd Mix| large|             10|
# |Australian Cattle...|medium|             13|
# |       Dachshund Mix| small|             14|
# |           Boxer Mix| large|              9|
# |Miniature Poodle Mix| small|             14|
# |   Border Collie Mix|medium|             12|
# |       Catahoula Mix| large|             12|
# |     Rat Terrier Mix| small|             16|
# |Australian Shephe...|medium|             13|
# |Yorkshire Terrier...| small|             14|
# |  Siberian Husky Mix|medium|             13|
# |Jack Russell Terr...| small|             15|
# +--------------------+------+---------------+

# %%
#read in the uncleaned shelter info 
from pyspark import SparkFiles
url = "https://c-geisel-bucket.s3.amazonaws.com/aac_shelter_outcomes.csv"
spark.sparkContext.addFile(url)
uncleaned_shelter_df = spark.read.csv(SparkFiles.get("aac_shelter_outcomes.csv"), sep=",", header=True, inferSchema=True)
uncleaned_shelter_df.show()
# Out:
# +----------------+---------+-----------+--------------------+-------------------+-------------------+-------------------+-------------------+-----------+---------------+---------------+----------------+
# |age_upon_outcome|animal_id|animal_type|               breed|              color|      date_of_birth|           datetime|          monthyear|       name|outcome_subtype|   outcome_type|sex_upon_outcome|
# +----------------+---------+-----------+--------------------+-------------------+-------------------+-------------------+-------------------+-----------+---------------+---------------+----------------+
# |         2 weeks|  A684346|        Cat|Domestic Shorthai...|       Orange Tabby|2014-07-07 00:00:00|2014-07-22 16:04:00|2014-07-22 16:04:00|       null|        Partner|       Transfer|     Intact Male|
# |          1 year|  A666430|        Dog|          Beagle Mix|        White/Brown|2012-11-06 00:00:00|2013-11-07 11:47:00|2013-11-07 11:47:00|       Lucy|        Partner|       Transfer|   Spayed Female|
# |          1 year|  A675708|        Dog|            Pit Bull|         Blue/White|2013-03-31 00:00:00|2014-06-03 14:20:00|2014-06-03 14:20:00|    *Johnny|           null|       Adoption|   Neutered Male|
# |         9 years|  A680386|        Dog|Miniature Schnauz...|              White|2005-06-02 00:00:00|2014-06-15 15:50:00|2014-06-15 15:50:00|     Monday|        Partner|       Transfer|   Neutered Male|
# |        5 months|  A683115|      Other|             Bat Mix|              Brown|2014-01-07 00:00:00|2014-07-07 14:04:00|2014-07-07 14:04:00|       null|    Rabies Risk|     Euthanasia|         Unknown|
# |        4 months|  A664462|        Dog|      Leonberger Mix|        Brown/White|2013-06-03 00:00:00|2013-10-07 13:06:00|2013-10-07 13:06:00|     *Edgar|        Partner|       Transfer|     Intact Male|
# |          1 year|  A693700|      Other|        Squirrel Mix|                Tan|2013-12-13 00:00:00|2014-12-13 12:20:00|2014-12-13 12:20:00|       null|      Suffering|     Euthanasia|         Unknown|
# |         3 years|  A692618|        Dog|Chihuahua Shortha...|              Brown|2011-11-23 00:00:00|2014-12-08 15:55:00|2014-12-08 15:55:00|      *Ella|        Partner|       Transfer|   Spayed Female|
# |         1 month|  A685067|        Cat|Domestic Shorthai...|   Blue Tabby/White|2014-06-16 00:00:00|2014-08-14 18:45:00|2014-08-14 18:45:00|       Lucy|           null|       Adoption|   Intact Female|
# |        3 months|  A678580|        Cat|Domestic Shorthai...|        White/Black|2014-03-26 00:00:00|2014-06-29 17:45:00|2014-06-29 17:45:00|     *Frida|        Offsite|       Adoption|   Spayed Female|
# |          1 year|  A675405|        Cat|Domestic Medium H...|        Black/White|2013-03-27 00:00:00|2014-03-28 14:55:00|2014-03-28 14:55:00|Stella Luna|           null|Return to Owner|   Spayed Female|
# |         2 years|  A673652|        Dog|Papillon/Border C...|        Black/White|2012-02-28 00:00:00|2014-03-28 14:39:00|2014-03-28 14:39:00|      Fancy|        Partner|       Transfer|   Neutered Male|
# |        2 months|  A677679|        Dog|Chihuahua Shortha...|              Black|2014-03-07 00:00:00|2014-05-26 19:10:00|2014-05-26 19:10:00|       Kash|         Foster|       Adoption|   Neutered Male|
# |         4 years|  A640655|        Dog|Miniature Schnauz...|              White|2009-04-27 00:00:00|2014-04-25 11:17:00|2014-04-25 11:17:00|      Sandy|           null|Return to Owner|   Spayed Female|
# |         8 years|  A690350|        Dog|Labrador Retrieve...|              Black|2006-10-18 00:00:00|2014-10-26 18:20:00|2014-10-26 18:20:00|        Shy|           null|Return to Owner|   Neutered Male|
# |         2 years|  A680396|        Dog|     Rat Terrier Mix|        White/Black|2012-06-02 00:00:00|2014-06-15 15:11:00|2014-06-15 15:11:00|    *Truman|        Partner|       Transfer|   Neutered Male|
# |          1 year|  A674298|        Dog|        Pit Bull Mix|Brown Brindle/White|2013-03-11 00:00:00|2014-04-16 12:51:00|2014-04-16 12:51:00|      *Newt|        Partner|       Transfer|   Neutered Male|
# |         3 weeks|  A670420|        Cat|Domestic Shorthai...|        Black/White|2013-12-16 00:00:00|2014-01-09 19:29:00|2014-01-09 19:29:00|       null|        Partner|       Transfer|     Intact Male|
# |        2 months|  A692378|        Dog|German Shepherd/L...|        Black/White|2014-10-19 00:00:00|2014-12-21 18:20:00|2014-12-21 18:20:00|    *Bonnie|         Foster|       Adoption|   Spayed Female|
# |        2 months|  A684460|        Cat|Domestic Shorthai...|        Brown Tabby|2014-06-02 00:00:00|2014-08-13 15:04:00|2014-08-13 15:04:00|       Elsa|           null|       Adoption|   Spayed Female|
# +----------------+---------+-----------+--------------------+-------------------+-------------------+-------------------+-------------------+-----------+---------------+---------------+----------------+
# only showing top 20 rows

# %% [markdown]
# ###Turn Spark DataFrames into Pandas Dataframes

# %%
#turn this into a pandas dataframe 
import pandas as pd

# %%
df = uncleaned_shelter_df.toPandas()

# %%
df.head()
# Out:
#   age_upon_outcome animal_id  ... outcome_type sex_upon_outcome
# 0          2 weeks   A684346  ...     Transfer      Intact Male
# 1           1 year   A666430  ...     Transfer    Spayed Female
# 2           1 year   A675708  ...     Adoption    Neutered Male
# 3          9 years   A680386  ...     Transfer    Neutered Male
# 4         5 months   A683115  ...   Euthanasia          Unknown
#
# [5 rows x 12 columns]

# %%
breed_df = dog_breed_df.toPandas()

# %%
breed_df.head(5)
# Out:
#                        Breed    Size  life_expectancy
# 0               Pit Bull Mix   large               11
# 1    Chihuahua Shorthair Mix   small               15
# 2     Labrador Retriever Mix  large                13
# 3        German Shepherd Mix   large               10
# 4  Australian Cattle Dog Mix  medium               13

# %%
breed_df = breed_df.rename(columns={'Breed': 'breed'})

# %%
breed_df.head(5)
# Out:
#                        breed    Size  life_expectancy
# 0               Pit Bull Mix   large               11
# 1    Chihuahua Shorthair Mix   small               15
# 2     Labrador Retriever Mix  large                13
# 3        German Shepherd Mix   large               10
# 4  Australian Cattle Dog Mix  medium               13

# %% [markdown]
# ###Clean the shelter dataframe

# %%
#Filter so that only dog data is shown
dfdogs = df[df["animal_type"] == "Dog"]

# %%
dfdogs
# Out:
#       age_upon_outcome animal_id  ... outcome_type sex_upon_outcome
# 1               1 year   A666430  ...     Transfer    Spayed Female
# 2               1 year   A675708  ...     Adoption    Neutered Male
# 3              9 years   A680386  ...     Transfer    Neutered Male
# 5             4 months   A664462  ...     Transfer      Intact Male
# 7              3 years   A692618  ...     Transfer    Spayed Female
# ...                ...       ...  ...          ...              ...
# 78250          1 month   A764895  ...     Adoption    Neutered Male
# 78251          1 month   A764894  ...     Adoption    Spayed Female
# 78252          3 years   A764468  ...     Adoption    Neutered Male
# 78254         2 months   A765858  ...     Adoption    Spayed Female
# 78255         2 months   A765857  ...     Adoption    Neutered Male
#
# [44242 rows x 12 columns]

# %%
#drop unnecessary columns
dfdogs_cleaned = dfdogs.drop(columns = ["age_upon_outcome", "animal_type", "color", "name", "outcome_subtype", "monthyear"])

# %%
dfdogs_cleaned.head(15)
# Out:
#    animal_id  ... sex_upon_outcome
# 1    A666430  ...    Spayed Female
# 2    A675708  ...    Neutered Male
# 3    A680386  ...    Neutered Male
# 5    A664462  ...      Intact Male
# 7    A692618  ...    Spayed Female
# 11   A673652  ...    Neutered Male
# 12   A677679  ...    Neutered Male
# 13   A640655  ...    Spayed Female
# 14   A690350  ...    Neutered Male
# 15   A680396  ...    Neutered Male
# 16   A674298  ...    Neutered Male
# 18   A692378  ...    Spayed Female
# 22   A666660  ...    Spayed Female
# 25   A689952  ...    Spayed Female
# 26   A669621  ...    Intact Female
#
# [15 rows x 6 columns]

# %%
#change the datatype of the date columns
dfdogs_cleaned["date_of_birth"] = pd.to_datetime(dfdogs_cleaned["date_of_birth"])
dfdogs_cleaned["datetime"] = pd.to_datetime(dfdogs_cleaned["datetime"])

# %%
dfdogs_cleaned.head(15)
# Out:
#    animal_id  ... sex_upon_outcome
# 1    A666430  ...    Spayed Female
# 2    A675708  ...    Neutered Male
# 3    A680386  ...    Neutered Male
# 5    A664462  ...      Intact Male
# 7    A692618  ...    Spayed Female
# 11   A673652  ...    Neutered Male
# 12   A677679  ...    Neutered Male
# 13   A640655  ...    Spayed Female
# 14   A690350  ...    Neutered Male
# 15   A680396  ...    Neutered Male
# 16   A674298  ...    Neutered Male
# 18   A692378  ...    Spayed Female
# 22   A666660  ...    Spayed Female
# 25   A689952  ...    Spayed Female
# 26   A669621  ...    Intact Female
#
# [15 rows x 6 columns]

# %%
#Filter the dataframe to show only the top 15 dog breeds
top_breeds = ['Pit Bull Mix', 'Chihuahua Shorthair Mix', 'Labrador Retriever Mix', 'German Shepherd Mix', 'Australian Cattle Dog Mix',
              'Dachshund Mix', 'Boxer Mix', 'Miniature Poodle Mix', 'Border Collie Mix', 'Catahoula Mix', 'Rat Terrier Mix', 
              'Australian Shepherd Mix', 'Yorkshire Terrier Mix', 'Siberian Husky Mix', 'Jack Russell Terrier Mix']
dfdogs_cleaned = dfdogs_cleaned[dfdogs_cleaned.breed.isin(top_breeds)]

# %%
dfdogs_cleaned.head(10)
# Out:
#    animal_id                    breed  ...     outcome_type sex_upon_outcome
# 7    A692618  Chihuahua Shorthair Mix  ...         Transfer    Spayed Female
# 14   A690350   Labrador Retriever Mix  ...  Return to Owner    Neutered Male
# 15   A680396          Rat Terrier Mix  ...         Transfer    Neutered Male
# 16   A674298             Pit Bull Mix  ...         Transfer    Neutered Male
# 27   A667311   Labrador Retriever Mix  ...         Adoption    Spayed Female
# 28   A690699  Chihuahua Shorthair Mix  ...         Transfer    Intact Female
# 32   A669918   Labrador Retriever Mix  ...         Adoption    Spayed Female
# 34   A678098   Labrador Retriever Mix  ...         Adoption    Neutered Male
# 36   A677038  Chihuahua Shorthair Mix  ...         Adoption    Spayed Female
# 37   A665344  Chihuahua Shorthair Mix  ...         Adoption    Spayed Female
#
# [10 rows x 6 columns]

# %%
#reset the dataframe index
dfdogs_cleaned.reset_index(drop=True)
# Out:
#       animal_id                    breed  ...     outcome_type sex_upon_outcome
# 0       A692618  Chihuahua Shorthair Mix  ...         Transfer    Spayed Female
# 1       A690350   Labrador Retriever Mix  ...  Return to Owner    Neutered Male
# 2       A680396          Rat Terrier Mix  ...         Transfer    Neutered Male
# 3       A674298             Pit Bull Mix  ...         Transfer    Neutered Male
# 4       A667311   Labrador Retriever Mix  ...         Adoption    Spayed Female
# ...         ...                      ...  ...              ...              ...
# 23845   A738395  Chihuahua Shorthair Mix  ...         Adoption    Neutered Male
# 23846   A761266        Border Collie Mix  ...  Return to Owner    Spayed Female
# 23847   A725872      German Shepherd Mix  ...  Return to Owner    Intact Female
# 23848   A761265        Border Collie Mix  ...  Return to Owner    Neutered Male
# 23849   A765857   Labrador Retriever Mix  ...         Adoption    Neutered Male
#
# [23850 rows x 6 columns]

# %%
#turn the cleaned dataframe back into a spark dataframe so that it can be written into the RDS instance
dfdogs_cleaned_spark = spark.createDataFrame(dfdogs_cleaned)

# %%
dfdogs_cleaned_spark.show()
# Out:
# +---------+--------------------+-------------------+-------------------+---------------+----------------+
# |animal_id|               breed|      date_of_birth|           datetime|   outcome_type|sex_upon_outcome|
# +---------+--------------------+-------------------+-------------------+---------------+----------------+
# |  A692618|Chihuahua Shortha...|2011-11-23 00:00:00|2014-12-08 15:55:00|       Transfer|   Spayed Female|
# |  A690350|Labrador Retrieve...|2006-10-18 00:00:00|2014-10-26 18:20:00|Return to Owner|   Neutered Male|
# |  A680396|     Rat Terrier Mix|2012-06-02 00:00:00|2014-06-15 15:11:00|       Transfer|   Neutered Male|
# |  A674298|        Pit Bull Mix|2013-03-11 00:00:00|2014-04-16 12:51:00|       Transfer|   Neutered Male|
# |  A667311|Labrador Retrieve...|2013-09-01 00:00:00|2013-11-19 18:30:00|       Adoption|   Spayed Female|
# |  A690699|Chihuahua Shortha...|2014-06-17 00:00:00|2014-11-04 18:03:00|       Transfer|   Intact Female|
# |  A669918|Labrador Retrieve...|2013-09-30 00:00:00|2014-01-03 17:47:00|       Adoption|   Spayed Female|
# |  A678098|Labrador Retrieve...|2002-05-08 00:00:00|2014-07-09 11:54:00|       Adoption|   Neutered Male|
# |  A677038|Chihuahua Shortha...|2012-04-22 00:00:00|2014-04-26 13:00:00|       Adoption|   Spayed Female|
# |  A665344|Chihuahua Shortha...|2009-10-16 00:00:00|2013-11-02 17:47:00|       Adoption|   Spayed Female|
# |  A647382|   Border Collie Mix|2010-08-09 00:00:00|2013-10-13 15:10:00|       Adoption|   Spayed Female|
# |  A660098|        Pit Bull Mix|2011-08-03 00:00:00|2013-10-14 11:42:00|       Transfer|   Spayed Female|
# |  A693005|           Boxer Mix|2013-11-29 00:00:00|2014-12-01 18:30:00|Return to Owner|   Neutered Male|
# |  A545127|        Pit Bull Mix|2007-05-31 00:00:00|2014-05-04 15:20:00|     Euthanasia|   Spayed Female|
# |  A661023|Miniature Poodle Mix|2010-08-15 00:00:00|2013-10-15 11:14:00|       Adoption|   Neutered Male|
# |  A673648|        Pit Bull Mix|2011-02-28 00:00:00|2014-03-09 11:34:00|Return to Owner|   Intact Female|
# |  A674466|        Pit Bull Mix|2014-03-08 00:00:00|2014-03-13 14:58:00|       Transfer|     Intact Male|
# |  A677479|Chihuahua Shortha...|2013-04-25 00:00:00|2014-05-01 17:05:00|       Adoption|   Spayed Female|
# |  A688079|Labrador Retrieve...|2004-09-14 00:00:00|2014-09-14 16:59:00|Return to Owner|   Spayed Female|
# |  A666831|Chihuahua Shortha...|2012-11-07 00:00:00|2013-11-11 15:50:00|       Adoption|   Neutered Male|
# +---------+--------------------+-------------------+-------------------+---------------+----------------+
# only showing top 20 rows

# %% [markdown]
# ###Write the Cleaned Dataframes into tables in RDS

# %%
# Store environmental variable
from getpass import getpass
password = getpass('Whitedog24')
# Configure settings for RDS
mode = "append"
jdbc_url="jdbc:postgresql://dataviz.cbl71rrsnrzm.us-east-1.rds.amazonaws.com:5432/shelter_data"
config = {"user":"postgres",
          "password": "Whitedog24",
          "driver":"org.postgresql.Driver"}
# Out:
# Whitedog24··········

# %%
# Write breed_df to table in RDS (The csv that lexie made)
#must use a spark df
dog_breed_df.write.jdbc(url=jdbc_url, table='breed_info', mode=mode, properties=config)

# %%
# Write review_id_df to table in RDS (The data that is cleaned from kaggle)
#must use a spark df
dfdogs_cleaned_spark.write.jdbc(url=jdbc_url, table='shelter_info', mode=mode, properties=config)

# %% [markdown]
# ###Join the Two Tables on the Dog Breed Column

# %%
#Concatenate the two dataframes
shelter_df = dfdogs_cleaned.merge(breed_df, how='inner', on='breed', right_index=False)

# %%
shelter_df
# Out:
#       animal_id                    breed  ...   Size life_expectancy
# 0       A692618  Chihuahua Shorthair Mix  ...  small              15
# 1       A690699  Chihuahua Shorthair Mix  ...  small              15
# 2       A677038  Chihuahua Shorthair Mix  ...  small              15
# 3       A665344  Chihuahua Shorthair Mix  ...  small              15
# 4       A677479  Chihuahua Shorthair Mix  ...  small              15
# ...         ...                      ...  ...    ...             ...
# 23845   A765233            Catahoula Mix  ...  large              12
# 23846   A648633            Catahoula Mix  ...  large              12
# 23847   A689738            Catahoula Mix  ...  large              12
# 23848   A764311            Catahoula Mix  ...  large              12
# 23849   A764846            Catahoula Mix  ...  large              12
#
# [23850 rows x 8 columns]

# %% [markdown]
# ###Create a Machine Learning Model
